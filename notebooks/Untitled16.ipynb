# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/chira/Downloads/test123.xlsx')
# Out:
# C:\Users\chira\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.shape
# Out:
# (8323, 1241)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8323 entries, 0 to 8322
# Columns: 1241 entries, Contact ID to Target Account
# dtypes: bool(1), datetime64[ns](28), float64(572), int64(10), object(630)
# memory usage: 78.7+ MB

# %%
df.columns
# Out:
# Index(['Contact ID', 'First Name', 'Last Name',
#        ' Check the boxes below that apply to you',
#        '1. Are you an entrepreneur or industry expert who could boost sales with a book?',
#        '2. What is the #1 reason you’d want to write a book?',
#        '26th March 2020 ctf webinar attendee',
#        '3. What type of book would you want to write?',
#        '4. Why haven’t you already written your book?',
#        '5. My motivation level to write a book is...',
#        ...
#        'First Conversion.1', 'First Conversion Date.1',
#        'Number of Form Submissions.1', 'Recent Conversion.1',
#        'Recent Conversion Date.1', 'Ideal Customer Profile Tier',
#        'Number of blockers', 'Number of contacts with a buying role',
#        'Number of decision makers', 'Target Account'],
#       dtype='object', length=1241)

# %%
list(df)
# Out:
# ['Contact ID',
#  'First Name',
#  'Last Name',
#  ' Check the boxes below that apply to you',
#  '1. Are you an entrepreneur or industry expert who could boost sales with a book?',
#  '2. What is the #1 reason you’d want to write a book?',
#  '26th March 2020 ctf webinar attendee',
#  '3. What type of book would you want to write?',
#  '4. Why haven’t you already written your book?',
#  '5. My motivation level to write a book is...',
#  '7th-8th-9th March 2020 - 3 Day  Live event Economy',
#  '7th-8th-9th March 2020 - 3 Day  Live event Half Economy ',
#  '7th-8th-9th March 2020 - 3 Day  Live event Half Gold',
#  '7th-8th-9th March 2020 - 3 Day  Live event Half IY',
#  '7th-8th-9th March 2020 - 3 Day  Live event IY',
#  '7th-8th-9th March 2020 - 3 Day  Live event Platinum',
#  '7th-8th-9th March 2020 - 3 Day Live event Half Platinum 1 ',
#  '7th-8th-9th March 2020 - 3 Day \xa0Live event Gold',
#  'AK CTF 14th December 2019 Kensington Afternoon',
# ...
