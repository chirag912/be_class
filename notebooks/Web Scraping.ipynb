# %%
# !pip install BeautifulSoup
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\chira\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\chira\\AppData\\Local\\Temp\\pip-install-k2ws5bkc\\beautifulsoup_e280f2f4a2894466a0dd8de7a249eec0\\setup.py'"'"'; __file__='"'"'C:\\Users\\chira\\AppData\\Local\\Temp\\pip-install-k2ws5bkc\\beautifulsoup_e280f2f4a2894466a0dd8de7a249eec0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\chira\AppData\Local\Temp\pip-pip-egg-info-u28xmy7j'
#          cwd: C:\Users\chira\AppData\Local\Temp\pip-install-k2ws5bkc\beautifulsoup_e280f2f4a2894466a0dd8de7a249eec0\
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
# ...

# %%
from bs4 import BeautifulSoup

# %%
with open("/Users/chira/Desktop/seaborn.html") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    print(soup)

soup = BeautifulSoup("<html>a web page</html>", 'html.parser')
#print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>seaborn.load_dataset — seaborn 0.11.2 documentation</title>
# <link href="../_static/pygments.css" rel="stylesheet" type="text/css"/>
# <link href="../_static/bootstrap-sphinx.css" rel="stylesheet" type="text/css"/>
# <link href="../_static/plot_directive.css" rel="stylesheet" type="text/css"/>
# <link href="../_static/style.css?v=0.11.2" rel="stylesheet" type="text/css"/>
# <script data-url_root="../" id="documentation_options" src="../_static/documentation_options.js"></script>
# <script src="../_static/jquery.js"></script>
# <script src="../_static/underscore.js"></script>
# <script src="../_static/doctools.js"></script>
# <script src="../_static/language_data.js"></script>
# <script src="../_static/copybutton.js"></script>
# <link href="../_static/favicon.ico" rel="shortcut icon"/>
# ...
