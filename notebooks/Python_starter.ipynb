# %% [markdown]
# ## Install libraries

# %%
# !pip install pandas

# %% [markdown]
# ## Basic import of Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# ## Reading Data Using PAndas

# %%
# Read  CSV file

df = pd.read_csv("https://people.sc.fsu.edu/~jburkardt/data/csv/addresses.csv")

# %%
df
# Out:
#                     John       Doe                 120 jefferson st.  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %%
df.head(4)
# Out:
#             John       Doe                 120 jefferson st.  Riverside   NJ  \
# 0           Jack  McGinnis                      220 hobo Av.      Phila   PA
# 1  John "Da Man"    Repici                 120 Jefferson St.  Riverside   NJ
# 2        Stephen     Tyler  7452 Terrace "At the Plaza" road   SomeTown   SD
# 3            NaN  Blankman                               NaN   SomeTown   SD
#
#     08075
# 0    9119
# 1    8075
# 2   91234
# 3     298

# %%
df1 = pd.read_csv("/home/chirag/Documents/Cars.csv")

# %%
df1.tail(10)
# Out:
#      HP        MPG  VOL          SP         WT
# 71  162  23.203569  135  133.415985  44.013139
# 72  162  23.203569  132  133.140074  43.353123
# 73  140  19.086341  160  124.715241  52.997752
# 74  140  19.086341  129  121.864163  42.618698
# 75  175  18.762837  129  132.864163  42.778219
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
df1.head(13)
# Out:
#     HP        MPG  VOL          SP         WT
# 0   49  53.700681   89  104.185353  28.762059
# 1   55  50.013401   92  105.461264  30.466833
# 2   55  50.013401   92  105.461264  30.193597
# 3   70  45.696322   92  113.461264  30.632114
# 4   53  50.504232   92  104.461264  29.889149
# 5   70  45.696322   89  113.185353  29.591768
# 6   55  50.013401   92  105.461264  30.308480
# 7   62  46.716554   50  102.598513  15.847758
# 8   62  46.716554   50  102.598513  16.359484
# 9   80  42.299078   94  115.645204  30.920154
# 10  73  44.652834   89  111.185353  29.363341
# 11  92  39.354094   50  117.598513  15.753535
# 12  92  39.354094   99  122.105055  32.813592

# %%
df1
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
df1['HP'].dtype
# Out:
# dtype('int64')

# %%
df1.columns
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
df1.axes
# Out:
# [RangeIndex(start=0, stop=81, step=1),
#  Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')]

# %%
df1.size
# Out:
# 405

# %%
df1.ndim
# Out:
# 2

# %%
df1.shape
# Out:
# (81, 5)

# %%
df1.values
# Out:
# array([[ 49.        ,  53.70068138,  89.        , 104.1853528 ,
#          28.7620589 ],
#        [ 55.        ,  50.01340115,  92.        , 105.4612635 ,
#          30.46683298],
#        [ 55.        ,  50.01340115,  92.        , 105.4612635 ,
#          30.19359657],
#        [ 70.        ,  45.69632238,  92.        , 113.4612635 ,
#          30.63211391],
#        [ 53.        ,  50.50423183,  92.        , 104.4612635 ,
#          29.88914864],
#        [ 70.        ,  45.69632238,  89.        , 113.1853528 ,
#          29.59176832],
#        [ 55.        ,  50.01340115,  92.        , 105.4612635 ,
#          30.30847957],
#        [ 62.        ,  46.71655428,  50.        , 102.5985128 ,
#          15.84775807],
#        [ 62.        ,  46.71655428,  50.        , 102.5985128 ,
#          16.35948352],
#        [ 80.        ,  42.29907817,  94.        , 115.6452041 ,
#          30.92015417],
#        [ 73.        ,  44.65283424,  89.        , 111.1853528 ,
# ...

# %% [markdown]
# ## Summary of Dataset

# %%
df1.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
df1.std()
# Out:
# HP     57.113502
# MPG     9.131445
# VOL    22.301497
# SP     14.181432
# WT      7.492813
# dtype: float64

# %%
df1.var()
# Out:
# HP     3261.952160
# MPG      83.383283
# VOL     497.356790
# SP      201.113002
# WT       56.142247
# dtype: float64

# %%
df1.shape
# Out:
# (81, 5)

# %%
df1.head(50)
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# 5    70  45.696322   89  113.185353  29.591768
# 6    55  50.013401   92  105.461264  30.308480
# 7    62  46.716554   50  102.598513  15.847758
# 8    62  46.716554   50  102.598513  16.359484
# 9    80  42.299078   94  115.645204  30.920154
# 10   73  44.652834   89  111.185353  29.363341
# 11   92  39.354094   50  117.598513  15.753535
# 12   92  39.354094   99  122.105055  32.813592
# 13   73  44.652834   89  111.185353  29.378436
# 14   66  45.734893   89  108.185353  29.347279
# 15   73  44.652834   89  111.185353  29.604527
# 16   78  42.789909   91  114.369293  29.535784
# 17   92  39.354094   50  117.598513  16.194122
# 18   78  42.789909   91  114.369293  29.929394
# ...

# %%
df1.head(50).std()
# Out:
# HP     18.623268
# MPG     5.563403
# VOL    16.352944
# SP      6.170992
# WT      5.481131
# dtype: float64

# %%
dim = df1[['HP']]

# %%
dim.ndim
# Out:
# 2

# %%
dim
# Out:
#      HP
# 0    49
# 1    55
# 2    55
# 3    70
# 4    53
# ..  ...
# 76  322
# 77  238
# 78  263
# 79  295
# 80  236
#
# [81 rows x 1 columns]

# %%
df1.columns
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
df1['HP'].mean()
# Out:
# 117.46913580246914

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
# !pip install openpyxl
sample = pd.read_excel("/home/chirag/Desktop/Sample Data Set.xlsx")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 6.2 MB/s eta 0:00:0000:01
# ...

# %%
# Out:
# 2

# %% [markdown]
# ## DataFrames Group by Methods

# %%
sample.head()
# Out:
#    OrderID OrderType  OrderDate               CreatedOn  BranchID Category 1  \
# 0   436960       App 2022-08-01 2022-07-30 10:56:20.267        27     SPIRIT
# 1   436960       App 2022-08-01 2022-07-30 10:56:20.267        27     SPIRIT
# 2   438020       App 2022-08-02 2022-07-30 23:24:58.473         1  SPIRITIMP
# 3   438255       App 2022-08-01 2022-07-31 13:53:51.657         1       BEER
# 4   438255       App 2022-08-01 2022-07-31 13:53:51.657         1     SPIRIT
#
#   Category 2     Category 3  Country        SKU  \
# 0      VODKA      DOMSPIRIT    INDIA  SG0006777
# 1      VODKA      DOMSPIRIT    INDIA  SG0006775
# 2       MALT      IMPSPIRIT  IRELAND  SG0006884
# 3     STRONG  BEERSTRONGDOM    INDIA  SG0003241
# 4     WHISKY      DOMSPIRIT    INDIA  SG0001371
#
#                              ProductName        Pack  Quantity    Rate  \
# 0         MAGIC MOMENTS VERVE LEMON LUSH       750ML       1.0  1300.0
# ...

# %%
# Group data using orderID

df_order = sample.groupby(['OrderID'])

# %%
# Calculate mean value for each numeric col per each group

df_order.mean()
# Out:
# /tmp/ipykernel_273894/1778046237.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_order.mean()
#          BranchID  Quantity         Rate  DiscountAmount       Amount  \
# OrderID
# 436960       27.0  1.000000  1300.000000             0.0  1300.000000
# 438020        1.0  1.000000  5999.000000             0.0  5999.000000
# 438255        1.0  1.666667   711.666667             0.0   823.333333
# 438420       15.0  1.000000  3600.000000             0.0  3600.000000
# 438430       40.0  2.000000   527.500000             0.0  1055.000000
# ...           ...       ...          ...             ...          ...
# 484135       21.0  3.000000   600.000000             0.0  1800.000000
# 484140        1.0  3.500000   195.000000             0.0   720.000000
# ...

# %%
#calculate mean rate for each order id 

rate = sample.groupby('OrderID')[['Rate','Amount']].mean()

# %%
rate
# Out:
#                 Rate       Amount
# OrderID
# 436960   1300.000000  1300.000000
# 438020   5999.000000  5999.000000
# 438255    711.666667   823.333333
# 438420   3600.000000  3600.000000
# 438430    527.500000  1055.000000
# ...              ...          ...
# 484135    600.000000  1800.000000
# 484140    195.000000   720.000000
# 484145    320.000000   830.000000
# 484165   2500.000000  2500.000000
# 484170    200.000000  1600.000000
#
# [9066 rows x 2 columns]

# %%
rate.shape
# Out:
# (160, 2)

# %%
rate  =  sample.groupby('OrderID', sort=False)[['Rate']].mean()

# %%
rate
# Out:
#                 Rate
# OrderID
# 436960   1300.000000
# 438020   5999.000000
# 438255    711.666667
# 438420   3600.000000
# 438430    527.500000
# ...              ...
# 484140    195.000000
# 484145    320.000000
# 484165   2500.000000
# 484170    200.000000
# 457665           NaN
#
# [9066 rows x 1 columns]

# %%
rate.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 rate.index(sample)
#
# TypeError: 'Int64Index' object is not callable

# %%
rate.loc[436960]
# Out:
# Rate    1300.0
# Name: 436960, dtype: float64

# %%
sample.head()
# Out:
#    OrderID OrderType  OrderDate               CreatedOn  BranchID Category 1  \
# 0   436960       App 2022-08-01 2022-07-30 10:56:20.267        27     SPIRIT
# 1   436960       App 2022-08-01 2022-07-30 10:56:20.267        27     SPIRIT
# 2   438020       App 2022-08-02 2022-07-30 23:24:58.473         1  SPIRITIMP
# 3   438255       App 2022-08-01 2022-07-31 13:53:51.657         1       BEER
# 4   438255       App 2022-08-01 2022-07-31 13:53:51.657         1     SPIRIT
#
#   Category 2     Category 3  Country        SKU  \
# 0      VODKA      DOMSPIRIT    INDIA  SG0006777
# 1      VODKA      DOMSPIRIT    INDIA  SG0006775
# 2       MALT      IMPSPIRIT  IRELAND  SG0006884
# 3     STRONG  BEERSTRONGDOM    INDIA  SG0003241
# 4     WHISKY      DOMSPIRIT    INDIA  SG0001371
#
#                              ProductName        Pack  Quantity    Rate  \
# 0         MAGIC MOMENTS VERVE LEMON LUSH       750ML       1.0  1300.0
# ...

# %%
sub_sample = sample[sample['Rate'] > 3000.0]

# %%
sub_sample.head()
# Out:
#     OrderID OrderType  OrderDate               CreatedOn  BranchID Category 1  \
# 2    438020       App 2022-08-02 2022-07-30 23:24:58.473         1  SPIRITIMP
# 6    438420       App 2022-08-01 2022-07-31 17:18:34.210        15  SPIRITIMP
# 12   438690       App 2022-08-01 2022-07-31 21:36:07.680        26     SPIRIT
# 20   438725       App 2022-08-01 2022-08-01 11:10:13.070         7       WINE
# 94   438940       App 2022-08-01 2022-08-01 20:06:27.230         4  SPIRITIMP
#
#     Category 2 Category 3        Country        SKU  \
# 2         MALT  IMPSPIRIT        IRELAND  SG0006884
# 6       LIQUOR  IMPSPIRIT         FRANCE  SG0002450
# 12        MALT  DOMSPIRIT          INDIA  SG0007373
# 20  WHITE WINE    IMPWINE  UNITED STATES  SG0004639
# 94      LIQUOR  IMPSPIRIT        GERMANY  SG0001084
#
#                        ProductName   Pack  Quantity     Rate  DiscountAmount  \
# 2   BUSHMILLS 12 YEARS SINGLE MALT  700ML       1.0   5999.0             0.0
# ...

# %%
# select only rows where country is FRANCE

sub_sample1  = sample[sample['Country']=='FRANCE']

# %%
sub_sample1
# Out:
#        OrderID OrderType  OrderDate               CreatedOn  BranchID  \
# 6       438420       App 2022-08-01 2022-07-31 17:18:34.210        15
# 183     439130       App 2022-08-02 2022-08-02 16:53:49.747        19
# 294     439390       App 2022-08-03 2022-08-03 11:52:13.590        26
# 310     439410       App 2022-08-03 2022-08-03 13:02:15.643        11
# 547     439940       App 2022-08-04 2022-08-04 15:34:28.853        17
# ...        ...       ...        ...                     ...       ...
# 20312   483510       CRM 2022-09-30 2022-09-30 16:28:43.170        19
# 20327   483545       CRM 2022-09-30 2022-09-30 17:04:37.527        19
# 20328   483545       CRM 2022-09-30 2022-09-30 17:04:37.527        19
# 20332   483545       CRM 2022-09-30 2022-09-30 17:04:37.527        19
# 20577   484115       APP 2022-09-30 2022-09-30 21:16:40.333        13
#
#       Category 1 Category 2 Category 3 Country        SKU  \
# 6      SPIRITIMP     LIQUOR  IMPSPIRIT  FRANCE  SG0002450
# ...

# %% [raw]
# == equal
# <= less than equal
# => more than equal
# > more
# < less
# != not equal to

# %%
sample.head()
# Out:
#    OrderID OrderType  OrderDate               CreatedOn  BranchID Category 1  \
# 0   436960       App 2022-08-01 2022-07-30 10:56:20.267        27     SPIRIT
# 1   436960       App 2022-08-01 2022-07-30 10:56:20.267        27     SPIRIT
# 2   438020       App 2022-08-02 2022-07-30 23:24:58.473         1  SPIRITIMP
# 3   438255       App 2022-08-01 2022-07-31 13:53:51.657         1       BEER
# 4   438255       App 2022-08-01 2022-07-31 13:53:51.657         1     SPIRIT
#
#   Category 2     Category 3  Country        SKU  \
# 0      VODKA      DOMSPIRIT    INDIA  SG0006777
# 1      VODKA      DOMSPIRIT    INDIA  SG0006775
# 2       MALT      IMPSPIRIT  IRELAND  SG0006884
# 3     STRONG  BEERSTRONGDOM    INDIA  SG0003241
# 4     WHISKY      DOMSPIRIT    INDIA  SG0001371
#
#                              ProductName        Pack  Quantity    Rate  \
# 0         MAGIC MOMENTS VERVE LEMON LUSH       750ML       1.0  1300.0
# ...

# %%
sample.iloc[[0,7],[0,3]]
# Out:
#    OrderID               CreatedOn
# 0   436960 2022-07-30 10:56:20.267
# 7   438430 2022-07-31 17:33:04.163

# %%
sample.iloc[[0,4],0:6]
# Out:
#    OrderID OrderType  OrderDate               CreatedOn  BranchID Category 1
# 0   436960       App 2022-08-01 2022-07-30 10:56:20.267        27     SPIRIT
# 4   438255       App 2022-08-01 2022-07-31 13:53:51.657         1     SPIRIT
